# %%
ord('%') # 显示% 字符的ASCII值
# Out:
# 37

# %%
chr(47) # 显示47数值对应的ASCII的字符
# Out:
# '/'

# %%
digit_rank = (ord('0'),  ord('9'))
small_a_rank = (ord('a'), ord('z'))
big_a_rank = (ord('A'), ord('Z'))

display(digit_rank, small_a_rank, big_a_rank)
# Out:
# (48, 57)
# (97, 122)
# (65, 90)

# %%
import random

def random_char(start, end):
    random_n = random.randint(ord(start), ord(end))
    return chr(random_n)

# %%
def verify_code(length):  # 生成 length长度的验证码
    codes = []
    for _ in range(length):
        # 确认从哪个范围生成随机字符
         # 0代表数字范围， 1代表小写字母范围, 2大写字母范围
        rn = random.randint(0, 2) 
        # 三元操作符
        rank = ('0', '9') if rn == 0 else ('a', 'z') if rn == 1 else ('A', 'Z')
        
        codes.append(random_char(*rank))  # 提取元组的内容
        
    return ''.join(codes)

# %%
verify_code(6)
# Out:
# 'P4XenB'

# %%
any(('', None, (), 1))  # 给定容器中的元素，任意一个元素为True，则结果为True
# Out:
# True

# %%
all(({1}, 1, 2, 3))  # 给定容器中的元素，所有的元素都为True，则结果为True
# Out:
# True

# %%
# list的排序
datas = [('1001', 'disen', 20),
        ('1002', 'jack', 16),
        ('1003', 'lucy', 19)]
# key指定函数，接收列表的项(item),返回项中参与排序的元素位置
# datas.sort(key=lambda item: item[2])
datas
# Out:
# [('1002', 'jack', 16), ('1003', 'lucy', 19), ('1001', 'disen', 20)]

# %%
datas = [('1001', 'disen', 20),
        ('1002', 'jack', 16),
        ('1003', 'lucy', 19)]
# 返回新的列表
display(sorted(datas, key=lambda item:item[2])) 
display(datas)
# Out:
# [('1002', 'jack', 16), ('1003', 'lucy', 19), ('1001', 'disen', 20)]
# [('1001', 'disen', 20), ('1002', 'jack', 16), ('1003', 'lucy', 19)]

# %%
person = {'id':101, 'name':'disen'}
{value:key for key,value in person.items() }
# Out:
# {101: 'id', 'disen': 'name'}

# %%
person = {'id':101, 'name':'disen', 11.5:'score'}
person
# Out:
# {11.5: 'score', 'id': 101, 'name': 'disen'}

# %%
# 删除字典的key
del person[11.5]  # 不返回，直接删除
person
# Out:
# {'id': 101, 'name': 'disen'}

# %%
person.pop('name') # 弹出name的key,返回value
# Out:
# 'disen'

# %%
person = {'id':101, 'name':'disen', 'sex':'女'}
for key in person:  # 字典是可以被迭代的，参与迭代的是key
    print(key)
# Out:
# id
# name
# sex

# %%
person.setdefault('id', 1009)  # 如果id不存在，则赋予默认值，如果id存在,则不修改
person
# Out:
# {'id': 101, 'name': 'disen', 'sex': '女'}

# %%
person.update({'id': 1009, 'phone': '17791692095'})
person  # 更新
# Out:
# {'id': 1009, 'name': 'disen', 'phone': '17791692095', 'sex': '女'}

# %%
with open('persons.txt', 'w+') as f:
    for _ in range(1000):
        f.write(verify_code(6)+'\n')
print('写入完成')
# Out:
# 写入完成

# %%
with open('persons.txt', 'r') as f:
    for line in f:  # file对象也可以被迭代
        print(line, end='')
# Out:
# 753nS5
# 2qOkCV
# LJAl7N
# HE1909
# OxrNwB
# ChN18M
# 2yK4gQ
# 948dG4
# AI3cq7
# 5gnw55
# lW4i66
# 4sATW1
# zZwN26
# gX09bx
# cCBeFY
# mEpWh6
# I0EVZ4
# 8jVszv
# QiLmf8
# 9Mn2Q9
# 54El9K
# 72opQy
# Yt6116
# BN7ETB
# bU05j5
# iSF8Bi
# 5dQ0x7
# 8Sg0xw
# YRrRL7
# ZFVB57
# 8j0l7u
# F2697N
# NmJXa9
# yUsD79
# zEupZt
# mOEt57
# 6xcOoJ
# SZ0Y30
# 6SQ7sp
# E1RL1a
# jMDz1E
# h17sy8
# kSvEyb
# B6mS11
# f92qhk
# 905FV0
# l91Rkb
# C166B0
# E9szRp
# k9YSWj
# 56TUDd
# RUGl0Z
# 4Ms7f4
# 4W3jws
# IKXU2O
# cxU354
# Y4kKW0
# T9Uz1v
# 955WXc
# 0KVJZr
# pmb80Q
# E75Wf1
# BbC0ke
# KciAqf
# znIqZd
# T1qTb8
# 1G46U7
# 6755FV
# K1gDFP
# 2k1i6U
# YqpPN0
# 8XvJky
# U91Kn2
# UQ0shL
# 1UbE1H
# zNMrb0
# HTc8zm
# M2NstY
# cca1wU
# 42dSvU
# eJ5ti0
# qkqb11
# 0Y12X2
# zh4L3i
# b5Ot66
# e3P1F1
# OgmkPU
# zuVMi3
# cB4M0D
# xKoNk3
# q00zpo
# 97d0nT
# kk1L2l
# Tkl9aI
# 5953hv
# 3iWyF9
# 223JS1
# TIIrKd
# 12RQ0q
# x98ssD
# d69nd9
# j5TEuY
# z5J577
# 1M5tyW
# xzRPcu
# Cv0jog
# 1GN5u5
# cj31WB
# 6gAGVO
# b3CRRw
# 0RGi36
# ...
